# %% [markdown]
# <a href="https://colab.research.google.com/github/Ololade117/Inducing-Polysemanticity/blob/main/Learn_agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Agents have agency; ability to interact with the environment. An agent is a system that levarages on AI models to interact with it's environment to achieve a user defined objective. it has reasoning, planning and executing abilities. It is divided into two parts (i) The brain (ii) the body(tools)
